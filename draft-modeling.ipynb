# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PolynomialFeatures
from sklearn.preprocessing import QuantileTransformer, PowerTransformer

from sklearn.feature_selection import SelectKBest, RFE, f_regression, SequentialFeatureSelector

from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from sklearn.linear_model import LinearRegression, TweedieRegressor, LassoLars

from importlib import reload

import warnings
warnings.filterwarnings("ignore")

import wrangle as wr
sns.set(rc={'figure.facecolor':'fbf3e4','axes.facecolor':'fbf3e4'})
#sns.set(font_scale=1.5)
pd.options.display.float_format = '{:,.3f}'.format

# %%
from sklearn.metrics import explained_variance_score

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR

# %%
from sklearn.feature_selection import SelectKBest, RFE, f_regression, SequentialFeatureSelector

# %% [markdown]
# Evaluation:
# - as an absolute score - RMSE
# - as a percentage - Adjasted R2

# %% [markdown]
# Linear Regressions

# %% [markdown]
# ### Functions

# %%
def regression_errors(y_actual, y_predicted):
    '''
    this function accepts 
    y: actual results/array
    yhat: predictions/array
    k: feature size/integer
    calculates regression scores based on the baseline being median
    returns RMSE and adjacted R2
    '''
    # root mean squared error score
    RMSE = mean_squared_error(y_actual, y_predicted) ** .5
    # adjucted R^2 score
    ADJR2 = explained_variance_score(y_actual, y_predicted)
    return round(RMSE), round(ADJR2, 2)

# %%
def scale_zillow_quantile(train, validate, test):
    '''
    accepts train, validate, test data sets
    scales the data in each of them
    returns transformed data sets
    '''
    #count_columns = ['bedroomcnt', 'bathroomcnt']
    
    #col = train.columns[1:-1]
    col = ['bedrooms', 'bathrooms', 'sq_feet', 'lot_sqft', 'house_age']
    
    # create scalers
    #min_max_scaler = MinMaxScaler()    
    qt = QuantileTransformer(output_distribution='normal')
    qt.fit(train[col])
    train[col] = qt.transform(train[col])
    validate[col] = qt.transform(validate[col])
    test[col] = qt.transform(test[col])
    
    return train, validate, test

# %%
def select_kbest(X, y, k):
    '''
    the function accepts the X_train data set, y_train array and k-number of features to select
    runs the SelectKBest algorithm and returns the list of features to be selected for the modeling
    # !KBest doesn't depend on the model
    '''
    kbest = SelectKBest(f_regression, k=k)
    kbest.fit(X, y)
    return X.columns[kbest.get_support()].tolist()

# %%
def standard_scale_zillow(train, validate, test):
    '''
    accepts train, validate, test data sets
    scales the data in each of them
    returns transformed data sets
    '''

    col = ['bedrooms', 'bathrooms', 'sq_feet', 'lot_sqft', 'house_age']
    
    # create scalers
    scaler = StandardScaler()    
    #qt = QuantileTransformer(output_distribution='normal')
    scaler.fit(train[col])
    train[col] = scaler.transform(train[col])
    validate[col] = scaler.transform(validate[col])
    test[col] = scaler.transform(test[col])
    
    return train, validate, test

# %%
def run_model(X_train, X_validate, scaling):
    
    '''
    general function to run models with X_train and X_validate that were scaled
    '''

    for f in features:
        for key in models:
            # create a model
            model = models[key]
            # fit the model
            model.fit(X_train[features[f]], y_train)
            # predictions of the train set
            y_hat_train = model.predict(X_train[features[f]])
            # predictions of the validate set
            y_hat_validate = model.predict(X_validate[features[f]])
            # add train set predictions to the data frame
            predictions_train[key] = y_hat_train
            # add validate set predictions to the data frame
            predictions_validate[key] = y_hat_validate

            # calculate scores train set
            RMSE, R2 = regression_errors(y_train, y_hat_train)
            # calculate scores validation set
            RMSE_val, R2_val = regression_errors(y_validate, y_hat_validate)
            diff = np.abs(RMSE - RMSE_val)
            
            # add the score results to the scores Data Frame
            scores.loc[len(scores.index)] = [key, f, scaling, RMSE, R2, RMSE_val, R2_val, diff]

# %%
def run_model_standard():
    # runs regression models on the X_train scaled with StandardScaler()
    X1, X2, _ = wr.standard_scale_zillow(X_train, X_validate, X_test)
    run_model(X1, X2, 'standard')

# %%
def run_model_quantile():
    XQ1, XQ2, _ = wr.scale_zillow_quantile(X_train, X_validate, X_test)
    run_model(XQ1, XQ2, 'quantile')

# %%
def run_rfe():
    '''
    The function accepts the X_train data set, y_train array and k-number of features to select
    runs the RFE algorithm and returns the list of features to be selected for the modeling
    # !RFE depends on the model.
    This function uses Linear regression
    '''
    # scale the data
    X1, X2, _ = wr.standard_scale_zillow(X_train, X_validate, X_test)
    
    for key in models:
        # create a model
        model = models[key]
        
        # create a RFE feature selector
        rfe = RFE(model, n_features_to_select=4)
        rfe.fit(X1, y_train)
        
        # get the optimal features for every particular model
        f = X1.columns[rfe.get_support()].tolist()
        
        # fit the model with RFE features
        model.fit(X1[f], y_train)
        # predictions of the train set
        y_hat_train = model.predict(X1[f])
        # predictions of the validate set
        y_hat_validate = model.predict(X2[f])
        # add train set predictions to the data frame
        col_name = str(key)+'_rfe'
        predictions_train[col_name] = y_hat_train
        # add validate set predictions to the data frame
        predictions_validate[col_name] = y_hat_validate

        # calculate scores train set
        RMSE, R2 = regression_errors(y_train, y_hat_train)
        # calculate scores validation set
        RMSE_val, R2_val = regression_errors(y_validate, y_hat_validate)
        diff = np.abs(RMSE - RMSE_val)

        # add the score results to the scores Data Frame
        scores.loc[len(scores.index)] = [key, 'rfe', 'standard', RMSE, R2, RMSE_val, R2_val, diff]

# %%
def run_polynomial():
    # scale the data
    X1, X2, _ = wr.standard_scale_zillow(X_train, X_validate, X_test)
    
    # only bedroom / bathroom polynomial
    for f in features:
        # features[f] gives an access to the list of features in the dictionary
        
        # create a Polynomial feature transformer
        poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)
        poly.fit(X1[features[f]])
        # create a df with transformed features of the train set
        X1_poly = pd.DataFrame(
            poly.transform(X1[features[f]]),
            columns=poly.get_feature_names(X1[features[f]].columns),
            index=X1.index)
        X1_poly = pd.concat([X1_poly, X1.iloc[:, 2:]], axis=1)
        # create a df with transformed features for the validate set
        X2_poly = pd.DataFrame(
            poly.transform(X2[features[f]]),
            columns=poly.get_feature_names(X2[features[f]].columns),
            index=X2.index)
        X2_poly = pd.concat([X2_poly, X2.iloc[:, 2:]], axis=1)
        
        feature_name = str(f)+'_poly'
        
        for key in models:
            # create a model
            model = models[key]
            # fit the model
            model.fit(X1_poly, y_train)
            # predictions of the train set
            y_hat_train = model.predict(X1_poly)
            # predictions of the validate set
            y_hat_validate = model.predict(X2_poly)
            # add train set predictions to the data frame
            predictions_train[key] = y_hat_train
            # add validate set predictions to the data frame
            predictions_validate[key] = y_hat_validate

            # calculate scores train set
            RMSE, R2 = regression_errors(y_train, y_hat_train)
            # calculate scores validation set
            RMSE_val, R2_val = regression_errors(y_validate, y_hat_validate)
            diff = np.abs(RMSE - RMSE_val)
            
            # add the score results to the scores Data Frame
            scores.loc[len(scores.index)] = [key, feature_name, 'standard', RMSE, R2, RMSE_val, R2_val, diff]

# %%
def run_single():
    for f in single_corr:
        model = LinearRegression()
        model.fit(X1[[f]], y_train)
        # predictions of the train set
        y_hat_train = model.predict(X1[[f]])
        # predictions of the validate set
        y_hat_validate = model.predict(X2[[f]])
        # add train set predictions to the data frame
        predictions_train[key] = y_hat_train
        # add validate set predictions to the data frame
        predictions_validate[key] = y_hat_validate

        # calculate scores train set
        RMSE, R2 = regression_errors(y_train, y_hat_train)
        # calculate scores validation set
        RMSE_val, R2_val = regression_errors(y_validate, y_hat_validate)
        diff = np.abs(RMSE - RMSE_val)

        # add the score results to the scores Data Frame
        scores.loc[len(scores.index)] = ['Single Linear Regression', f, 'standard', RMSE, R2, RMSE_val, R2_val, diff]

# %%
reload(wr)
# Out:
# <module 'wrangle' from '/Users/nadina/codeup-data-science/zillow-project/wrangle.py'>

# %%
# get the zillow data
df = wr.get_zillow()

wr.dummies(df)
X_train, X_validate, X_test, y_train, y_validate, y_test = wr.full_split_zillow(df)

# %%
# create 3 data sets that keep the values of the counties
la = df[(df.Orange == 0) & (df.Ventura == 0)] # LA county
ventura = df[df.Ventura == 1] # Ventura county
orange = df[df.Orange == 1] # Orange county

# %%
baseline = y_train.median()
baseline
# Out:
# 362435.0

# %%
predictions_train = pd.DataFrame(y_train)
predictions_validate = pd.DataFrame(y_validate)
predictions_train['baseline'] = baseline
predictions_validate['baseline'] = baseline

# %%
X1, X2, X3 = wr.standard_scale_zillow(X_train, X_validate, X_test)

# %%
XQ1, XQ2, XQ3 = scale_zillow_quantile(X_train, X_validate, X_test)

# %%
seed = 2912

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Generalized Linear Model': TweedieRegressor(power=2, alpha = 0.5),
    'Gradient Boosting Regression': GradientBoostingRegressor(random_state=seed),
    'Decision Tree Regression': DecisionTreeRegressor(max_depth=4, random_state=seed),
    'Random Forest Regression':RandomForestRegressor(max_depth=4, random_state=seed),
    'LassoLars Regression':LassoLars(alpha=0.1)
    }

# %%
for key in models:
    print(models[key])
# Out:
# LinearRegression()
# TweedieRegressor(alpha=0.5, power=2)
# GradientBoostingRegressor(random_state=2912)
# DecisionTreeRegressor(max_depth=4, random_state=2912)
# RandomForestRegressor(max_depth=4, random_state=2912)
# LassoLars(alpha=0.1)

# %%
scores = pd.DataFrame(columns=['model_name', 'features', 'scaling',
                               'RMSE_train', 'R2_train', 'RMSE_validate', 'R2_validate', 'RMSE_difference'])

# %%
# select features with K-Best algorithm 
select_kbest(X_train, y_train, 3)
# Out:
# ['bedrooms', 'bathrooms', 'sq_feet']

# %%
f1 = ['bedrooms', 'bathrooms', 'sq_feet']
f2 = ['bedrooms', 'bathrooms']
f3 = ['bedrooms','bathrooms','sq_feet', 'pools']
f4 = ['bathrooms','sq_feet', 'pools']
f5 = ['bedrooms','bathrooms','sq_feet','house_age','pools','Orange','Ventura']
f6 = select_kbest(X_train, y_train, 4)
f7 = X_train.columns.tolist()

# create a dictionary with features
features = {
    'f1':f1,
    'f2':f2,
    'f3':f3,
    'f4':f4,
    'f5':f5,
    'f6':f6,
    'f7':f7
}

# %%
run_model_standard()

# %%
scores.sort_values(by='RMSE_train')
# Out:
#                       model_name features   scaling  RMSE_train  R2_train  \
# 38  Gradient Boosting Regression       f7  standard      269976     0.410
# 26  Gradient Boosting Regression       f5  standard      271862     0.400
# 32  Gradient Boosting Regression       f6  standard      277936     0.380
# 14  Gradient Boosting Regression       f3  standard      281581     0.360
# 2   Gradient Boosting Regression       f1  standard      282210     0.360
# 40      Random Forest Regression       f7  standard      282946     0.350
# 28      Random Forest Regression       f5  standard      284177     0.350
# 34      Random Forest Regression       f6  standard      284685     0.350
# 20  Gradient Boosting Regression       f4  standard      285209     0.340
# 39      Decision Tree Regression       f7  standard      285674     0.340
# 16      Random Forest Regression       f3  standard      286078     0.340
# 4       Random Forest Regression       f1  standard      286103     0.340
# 27      Decision Tree Regression       f5  standard      286165     0.340
# 33      Decision Tree Regression       f6  standard      286533     0.340
# 3       Decision Tree Regression       f1  standard      287583     0.330
# 15      Decision Tree Regression       f3  standard      287583     0.330
# 22      Random Forest Regression       f4  standard      287719     0.330
# 21      Decision Tree Regression       f4  standard      288388     0.330
# 36             Linear Regression       f7  standard      295933     0.290
# 41          LassoLars Regression       f7  standard      295933     0.290
# 24             Linear Regression       f5  standard      296641     0.290
# 29          LassoLars Regression       f5  standard      296641     0.290
# 17          LassoLars Regression       f3  standard      297759     0.290
# 12             Linear Regression       f3  standard      297759     0.290
# 30             Linear Regression       f6  standard      298357     0.280
# 35          LassoLars Regression       f6  standard      298357     0.280
# 5           LassoLars Regression       f1  standard      298497     0.280
# 0              Linear Regression       f1  standard      298497     0.280
# 37      Generalized Linear Model       f7  standard      299409     0.280
# 25      Generalized Linear Model       f5  standard      299538     0.280
# 13      Generalized Linear Model       f3  standard      300335     0.270
# 23          LassoLars Regression       f4  standard      300360     0.270
# 18             Linear Regression       f4  standard      300360     0.270
# 19      Generalized Linear Model       f4  standard      301021     0.270
# 1       Generalized Linear Model       f1  standard      301060     0.270
# 31      Generalized Linear Model       f6  standard      301062     0.270
# 8   Gradient Boosting Regression       f2  standard      307774     0.240
# 10      Random Forest Regression       f2  standard      307934     0.240
# 9       Decision Tree Regression       f2  standard      307975     0.240
# 7       Generalized Linear Model       f2  standard      329812     0.120
# 6              Linear Regression       f2  standard      330832     0.120
# 11          LassoLars Regression       f2  standard      330832     0.120
#
#     RMSE_validate  R2_validate  RMSE_difference
# 38         269407        0.400              569
# 26         270708        0.390             1154
# 32         276324        0.370             1612
# 14         280589        0.350              992
# 2          281158        0.350             1052
# 40         279782        0.350             3164
# 28         281244        0.350             2933
# 34         281324        0.350             3361
# 20         283665        0.330             1544
# 39         282026        0.340             3648
# 16         282632        0.340             3446
# 4          282643        0.340             3460
# 27         283305        0.340             2860
# 33         283273        0.340             3260
# 3          284137        0.330             3446
# 15         284137        0.330             3446
# 22         283655        0.330             4064
# 21         284318        0.330             4070
# 36         290617        0.300             5316
# 41         290617        0.300             5316
# 24         291545        0.300             5096
# 29         291545        0.300             5096
# 17         292535        0.290             5224
# 12         292535        0.290             5224
# 30         293341        0.290             5016
# 35         293341        0.290             5016
# 5          293440        0.290             5057
# 0          293440        0.290             5057
# 37         293760        0.290             5649
# 25         293900        0.290             5638
# 13         294626        0.280             5709
# 23         294946        0.280             5414
# 18         294945        0.280             5415
# 19         295307        0.280             5714
# 1          295396        0.280             5664
# 31         295396        0.280             5666
# 8          302498        0.240             5276
# 10         302758        0.240             5176
# 9          302902        0.240             5073
# 7          324689        0.130             5123
# 6          325968        0.120             4864
# 11         325968        0.120             4864

# %%
run_model_quantile()

# %%
scores.sort_values(by='RMSE_train').head(20)
# Out:
#                       model_name features   scaling  RMSE_train  R2_train  \
# 38  Gradient Boosting Regression       f7  standard      269976     0.410
# 80  Gradient Boosting Regression       f7  quantile      269976     0.410
# 26  Gradient Boosting Regression       f5  standard      271862     0.400
# 68  Gradient Boosting Regression       f5  quantile      271862     0.400
# 32  Gradient Boosting Regression       f6  standard      277936     0.380
# 74  Gradient Boosting Regression       f6  quantile      277936     0.380
# 14  Gradient Boosting Regression       f3  standard      281581     0.360
# 56  Gradient Boosting Regression       f3  quantile      281581     0.360
# 44  Gradient Boosting Regression       f1  quantile      282210     0.360
# 2   Gradient Boosting Regression       f1  standard      282210     0.360
# 40      Random Forest Regression       f7  standard      282946     0.350
# 82      Random Forest Regression       f7  quantile      282946     0.350
# 70      Random Forest Regression       f5  quantile      284177     0.350
# 28      Random Forest Regression       f5  standard      284177     0.350
# 76      Random Forest Regression       f6  quantile      284685     0.350
# 34      Random Forest Regression       f6  standard      284685     0.350
# 62  Gradient Boosting Regression       f4  quantile      285209     0.340
# 20  Gradient Boosting Regression       f4  standard      285209     0.340
# 81      Decision Tree Regression       f7  quantile      285674     0.340
# 39      Decision Tree Regression       f7  standard      285674     0.340
#
#     RMSE_validate  R2_validate  RMSE_difference
# 38         269407        0.400              569
# 80         269407        0.400              569
# 26         270708        0.390             1154
# 68         270709        0.390             1153
# 32         276324        0.370             1612
# 74         276321        0.370             1615
# 14         280589        0.350              992
# 56         280589        0.350              992
# 44         281158        0.350             1052
# 2          281158        0.350             1052
# 40         279782        0.350             3164
# 82         279782        0.350             3164
# 70         281244        0.350             2933
# 28         281244        0.350             2933
# 76         281324        0.350             3361
# 34         281324        0.350             3361
# 62         283665        0.330             1544
# 20         283665        0.330             1544
# 81         282026        0.340             3648
# 39         282026        0.340             3648

# %%
X_train.columns.tolist()[:-3]
# Out:
# ['bedrooms', 'bathrooms', 'sq_feet', 'lot_sqft', 'house_age']

# %%
rfe()

# %%
scores[scores.features == 'rfe']
# Out:
#                       model_name features   scaling  RMSE_train  R2_train  \
# 84             Linear Regression      rfe  standard      297363     0.290
# 85      Generalized Linear Model      rfe  standard      300300     0.270
# 86  Gradient Boosting Regression      rfe  standard      276467     0.380
# 87      Decision Tree Regression      rfe  standard      285684     0.340
# 88      Random Forest Regression      rfe  standard      283188     0.350
# 89          LassoLars Regression      rfe  standard      297363     0.290
#
#     RMSE_validate  R2_validate  RMSE_difference
# 84         292245        0.290             5118
# 85         294633        0.280             5667
# 86         274858        0.380             1609
# 87         281886        0.340             3798
# 88         279839        0.350             3349
# 89         292244        0.290             5119

# %%
polynomial()

# %%
scores.sort_values(by='RMSE_train')
# Out:
#             model_name features   scaling  RMSE_train  R2_train  \
# 38    Gradient Booster     poly  standard      267275     0.420
# 26    Gradient Booster     poly  standard      268026     0.420
# 32    Gradient Booster     poly  standard      269318     0.420
# 14    Gradient Booster     poly  standard      269612     0.410
# 2     Gradient Booster     poly  standard      269874     0.410
# 8     Gradient Booster     poly  standard      270423     0.410
# 20    Gradient Booster     poly  standard      271260     0.410
# 36   Linear Regression     poly  standard      277834     0.380
# 41           LassoLars     poly  standard      278870     0.370
# 24   Linear Regression     poly  standard      278981     0.370
# 29           LassoLars     poly  standard      279556     0.370
# 40       Random Forest     poly  standard      280048     0.370
# 28       Random Forest     poly  standard      280208     0.370
# 34       Random Forest     poly  standard      281545     0.360
# 16       Random Forest     poly  standard      282042     0.360
# 4        Random Forest     poly  standard      282162     0.360
# 22       Random Forest     poly  standard      282498     0.360
# 30   Linear Regression     poly  standard      282502     0.360
# 10       Random Forest     poly  standard      282899     0.350
# 35           LassoLars     poly  standard      283239     0.350
# 12   Linear Regression     poly  standard      283670     0.350
# 5            LassoLars     poly  standard      283698     0.350
# 0    Linear Regression     poly  standard      283698     0.350
# 39       Decision Tree     poly  standard      284348     0.350
# 27       Decision Tree     poly  standard      284363     0.350
# 17           LassoLars     poly  standard      284679     0.350
# 33       Decision Tree     poly  standard      284912     0.350
# 21       Decision Tree     poly  standard      285283     0.340
# 15       Decision Tree     poly  standard      285354     0.340
# 3        Decision Tree     poly  standard      285446     0.340
# 9        Decision Tree     poly  standard      285674     0.340
# 18   Linear Regression     poly  standard      286543     0.340
# 23           LassoLars     poly  standard      287612     0.330
# 37  General Regression     poly  standard      287649     0.330
# 25  General Regression     poly  standard      288302     0.330
# 6    Linear Regression     poly  standard      289612     0.320
# 11           LassoLars     poly  standard      289612     0.320
# 31  General Regression     poly  standard      291465     0.320
# 13  General Regression     poly  standard      292282     0.310
# 19  General Regression     poly  standard      293048     0.310
# 1   General Regression     poly  standard      293224     0.310
# 7   General Regression     poly  standard      301956     0.270
#
#     RMSE_validate  R2_validate  RMSE_difference
# 38         268978        0.400             1703
# 26         269271        0.400             1245
# 32         270113        0.400              795
# 14         270309        0.400              697
# 2          270087        0.400              213
# 8          270071        0.400              352
# 20         270856        0.390              404
# 36         273213        0.380             4621
# 41         273891        0.380             4979
# 24         274127        0.380             4854
# 29         274499        0.380             5057
# 40         277497        0.360             2551
# 28         277555        0.360             2653
# 34         278921        0.360             2624
# 16         279484        0.350             2558
# 4          279463        0.350             2699
# 22         279381        0.350             3117
# 30         276981        0.370             5521
# 10         279806        0.350             3093
# 35         277700        0.360             5539
# 12         278348        0.360             5322
# 5          278300        0.360             5398
# 0          278301        0.360             5397
# 39         281278        0.350             3070
# 27         281161        0.350             3202
# 17         279569        0.350             5110
# 33         281869        0.340             3043
# 21         281912        0.340             3371
# 15         282483        0.340             2871
# 3          282554        0.340             2892
# 9          282026        0.340             3648
# 18         281286        0.350             5257
# 23         282414        0.340             5198
# 37         290235        0.300             2586
# 25         290549        0.300             2247
# 6          283428        0.340             6184
# 11         283428        0.340             6184
# 31         291573        0.300              108
# 13         296726        0.270             4444
# 19         298551        0.260             5503
# 1          296258        0.270             3034
# 7          296232        0.270             5724

# %%
scores[scores.model_name == 'Generalized Linear Model']
# Out:
#                   model_name features   scaling  RMSE_train  R2_train  \
# 1   Generalized Linear Model       f1  standard      301060     0.270
# 7   Generalized Linear Model       f2  standard      329812     0.120
# 13  Generalized Linear Model       f3  standard      300335     0.270
# 19  Generalized Linear Model       f4  standard      301021     0.270
# 25  Generalized Linear Model       f5  standard      299538     0.280
# 31  Generalized Linear Model       f6  standard      301062     0.270
# 37  Generalized Linear Model       f7  standard      299409     0.280
# 43  Generalized Linear Model       f1  quantile      301360     0.270
# 49  Generalized Linear Model       f2  quantile      327920     0.130
# 55  Generalized Linear Model       f3  quantile      300634     0.270
# 61  Generalized Linear Model       f4  quantile      301413     0.270
# 67  Generalized Linear Model       f5  quantile      299811     0.280
# 73  Generalized Linear Model       f6  quantile      301362     0.270
# 79  Generalized Linear Model       f7  quantile      299690     0.280
# 85  Generalized Linear Model      rfe  standard      300300     0.270
#
#     RMSE_validate  R2_validate  RMSE_difference
# 1          295396        0.280             5664
# 7          324689        0.130             5123
# 13         294626        0.280             5709
# 19         295307        0.280             5714
# 25         293900        0.290             5638
# 31         295396        0.280             5666
# 37         293760        0.290             5649
# 43         295695        0.280             5665
# 49         322781        0.140             5139
# 55         294930        0.280             5704
# 61         295702        0.280             5711
# 67         294179        0.280             5632
# 73         295698        0.280             5664
# 79         294043        0.290             5647
# 85         294633        0.280             5667

# %%
mean_squared_error(y_train, yhat_train) ** .5, explained_variance_score(y_train, yhat_train)
# Out:
# (283143.73749297264, 0.35151216724266465)

# %%
regression_errors(y_train, yhat_train)
# Out:
# (283144, 0.35)

# %%
regression_errors(y_train, predictions_train.baseline, 3)
# Out:
# (351606, 0.05)

# %%
single_corr = X1.iloc[:, :-3].columns.tolist()

# %%
single_corr
# Out:
# ['bedrooms', 'bathrooms', 'sq_feet', 'lot_sqft', 'house_age']

# %%
run_single()

# %%
scores[scores.model_name == 'Single Linear Regression']
# Out:
#                   model_name   features   scaling  RMSE_train  R2_train  \
# 90  Single Linear Regression   bedrooms  standard      342329     0.060
# 91  Single Linear Regression  bathrooms  standard      331662     0.110
# 92  Single Linear Regression    sq_feet  standard      301680     0.270
# 93  Single Linear Regression   lot_sqft  standard      348182     0.020
# 94  Single Linear Regression  house_age  standard      342565     0.050
#
#     RMSE_validate  R2_validate  RMSE_difference
# 90         336890        0.060             5439
# 91         327084        0.120             4578
# 92         296552        0.270             5128
# 93         343313        0.030             4869
# 94         337964        0.060             4601

# %%
def run_all_models():
    run_model_standard()
    run_model_quantile()
    run_rfe()
    run_polynomial()
    run_single()

# %%
scores
# Out:
# Empty DataFrame
# Columns: [model_name, features, scaling, RMSE_train, R2_train, RMSE_validate, R2_validate, RMSE_difference]
# Index: []

# %%
run_all_models()

# %%
scores.shape
# Out:
# (137, 8)

# %%
def select_best_model(scores):
    # select top 20 models based on the RMSE score of the train set
    top_20 = scores.sort_values(by='RMSE_train').head(20)
    # select top 5 models based on the RMSE score of the validate set
    top_5 = top_20.sort_values(by=['RMSE_validate']).head(5)
    # display top 5 models
    display(top_5)
    # select the best model with the smallest difference in the RMSE scores
    best_model = top_5.sort_values(by='RMSE_difference').head(1)
    return best_model

# %%
best = select_best_model(scores)
# Out:
#                        model_name features   scaling  RMSE_train  R2_train  \
# 128  Gradient Boosting Regression  f7_poly  standard      267275     0.420
# 116  Gradient Boosting Regression  f5_poly  standard      268026     0.420
# 80   Gradient Boosting Regression       f7  quantile      269976     0.410
# 38   Gradient Boosting Regression       f7  standard      269976     0.410
# 98   Gradient Boosting Regression  f2_poly  standard      270423     0.410
#
#      RMSE_validate  R2_validate  RMSE_difference
# 128         268978        0.400             1703
# 116         269271        0.400             1245
# 80          269407        0.400              569
# 38          269407        0.400              569
# 98          270071        0.400              352

# %%
best
# Out:
#                       model_name features   scaling  RMSE_train  R2_train  \
# 98  Gradient Boosting Regression  f2_poly  standard      270423     0.410
#
#     RMSE_validate  R2_validate  RMSE_difference
# 98         270071        0.400              352

# %%
top_20 = scores.sort_values(by='RMSE_train').head(20)

# %%
top_5 = top_20.sort_values(by=['RMSE_validate']).head(5)

# %%
top_5
# Out:
#                        model_name features   scaling  RMSE_train  R2_train  \
# 128  Gradient Boosting Regression  f7_poly  standard      267275     0.420
# 116  Gradient Boosting Regression  f5_poly  standard      268026     0.420
# 80   Gradient Boosting Regression       f7  quantile      269976     0.410
# 38   Gradient Boosting Regression       f7  standard      269976     0.410
# 98   Gradient Boosting Regression  f2_poly  standard      270423     0.410
#
#      RMSE_validate  R2_validate  RMSE_difference
# 128         268978        0.400             1703
# 116         269271        0.400             1245
# 80          269407        0.400              569
# 38          269407        0.400              569
# 98          270071        0.400              352

# %%
best_model = top_5.sort_values(by='RMSE_difference').head(1)

# %%
best_model
# Out:
#                       model_name features   scaling  RMSE_train  R2_train  \
# 98  Gradient Boosting Regression  f2_poly  standard      270423     0.410
#
#     RMSE_validate  R2_validate  RMSE_difference
# 98         270071        0.400              352

# %%
str(f2)
# Out:
# "['bedrooms', 'bathrooms']"

# %%
def run_best_model():
    '''
    the function runs the best model on the train, test and validate data sets 
    and returns scores in the data frame
    '''
    # create a data frame for test set results
    predictions_test = pd.DataFrame(y_test)
    predictions_test['baseline'] = baseline

    f = f2
    poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)
    poly.fit(X1[f])

    # create a df with transformed features of the train set
    X1_poly = pd.DataFrame(
                poly.transform(X1[f]),
                columns=poly.get_feature_names(X1[f].columns),
                index=X1.index)
    X1_poly = pd.concat([X1_poly, X1.iloc[:, 2:]], axis=1)

    # create a df with transformed features for the validate set
    X2_poly = pd.DataFrame(
                poly.transform(X2[f]),
                columns=poly.get_feature_names(X2[f].columns),
                index=X2.index)
    X2_poly = pd.concat([X2_poly, X2.iloc[:, 2:]], axis=1)

    # create a df with transformed features for the validate set
    X2_poly = pd.DataFrame(
                poly.transform(X2[f]),
                columns=poly.get_feature_names(X2[f].columns),
                index=X2.index)
    X2_poly = pd.concat([X2_poly, X2.iloc[:, 2:]], axis=1)

    # create. df with transformed features for the test set
    X3_poly = pd.DataFrame(
                poly.transform(X3[f]),
                columns=poly.get_feature_names(X3[f].columns),
                index=X3.index)
    X3_poly = pd.concat([X3_poly, X3.iloc[:, 2:]], axis=1)

    # create a Gradient Boosting Regression model
    model = GradientBoostingRegressor()
    # fit the model
    model.fit(X1_poly, y_train)
    # predictions of the train set
    y_hat_train = model.predict(X1_poly)
    # predictions of the validate set
    y_hat_validate = model.predict(X2_poly)
    # add train set predictions to the data frame
    y_hat_test = model.predict(X3_poly)
    predictions_test['predictions'] = y_hat_test

    # calculate scores train set
    RMSE_train, R2_train = regression_errors(y_train, y_hat_train)
    # calculate scores validation set
    RMSE_val, R2_val = regression_errors(y_validate, y_hat_validate)
    # calculate scores test set
    RMSE_test, R2_test = regression_errors(y_test, y_hat_test)
    RMSE_bl, _ = regression_errors(y_test, predictions_test.baseline)
    
    # save final score into a dictionary
    res = {
        'Features': str(f),
        'RMSE Train Set': RMSE_train,
        'RMSE Validation Set':RMSE_val,
        'RMSE Test Set':RMSE_test,
        'R2 Train Set':R2_train,
        'R2 Validation Set':R2_val,
        'R2 Test':R2_test,
        'Beats a basline by:':str(f'{round((RMSE_bl - RMSE_test) / RMSE_bl * 100, 1)}%')
    }

    # add the score results to the scores Data Frame
    final_test = pd.DataFrame({'Gradient Bosting Regression': list(res.keys()), 'Scores': list(res.values())})

    return final_test

# %%
run_best_model()
# Out:
#   Gradient Bosting Regression                     Scores
# 0                    Features  ['bedrooms', 'bathrooms']
# 1              RMSE Train Set                     270423
# 2         RMSE Validation Set                     270075
# 3               RMSE Test Set                     273441
# 4                R2 Train Set                      0.410
# 5           R2 Validation Set                      0.400
# 6                     R2 Test                      0.380
# 7         Beats a basline by:                      23.5%

# %%
RMSE_test
# Out:
# 273443

# %%
RMSE_bl
# Out:
# 357599

# %%
RMSE_bl
# Out:
# 0.7646637714311282

# %%
R2_test

# %%
RMSE_val - RMSE_test
# Out:
# -3366

# %%
(RMSE_bl - RMSE_test)
# Out:
# 84156

# %%
round((RMSE_bl - RMSE_test) / RMSE_bl * 100, 1)
# Out:
# 23.5

# %%
RMSE_bl/RMSE_test
# Out:
# 1.3077738890656485

# %%
# add the score results to the scores Data Frame
final_test = pd.DataFrame({'Gradient Bosting Regression': list(res.keys()), 'Scores': list(res.values())})

# %%
final_test
# Out:
#   Gradient Bosting Regression                     Scores
# 0                    Features  ['bedrooms', 'bathrooms']
# 1              RMSE Train Set                     270423
# 2         RMSE Validation Set                     270077
# 3               RMSE Test Set                     273443
# 4                R2 Train Set                      0.410
# 5           R2 Validation Set                      0.400
# 6                     R2 Test                      0.380
# 7         Beats a basline by:                      23.5%

# %%
res = {
    'Features': str(f),
    'RMSE Train Set': RMSE_train,
    'RMSE Validation Set':RMSE_val,
    'RMSE Test Set':RMSE_test,
    'R2 Train Set':R2_train,
    'R2 Validation Set':R2_val,
    'R2 Test':R2_test,
    'Beats a basline by:':str(f'{round((RMSE_bl - RMSE_test) / RMSE_bl * 100, 1)}%')
}

# %% [raw]
# predictions_test['baseline'] = baseline

# %%
predictions_test
# Out:
#        home_value    baseline
# 43192     1292346 362,435.000
# 715        677817 362,435.000
# 35134       63565 362,435.000
# 25346     1522890 362,435.000
# 33799      319803 362,435.000
# ...           ...         ...
# 5434       556697 362,435.000
# 43165      348165 362,435.000
# 7890       912304 362,435.000
# 23816      262387 362,435.000
# 6496       229851 362,435.000
#
# [10032 rows x 2 columns]
